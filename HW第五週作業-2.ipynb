# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display,HTML,Markdown,Image,YouTubeVideo

# %%
from ipywidgets import interact
from ipywidgets import interact_manual

# %% [markdown]
# # 作業二：景點推薦機器人

# %%
pc1=Image('大阪城.jpg')
pc2=Image('羅馬競技場.jpg')
pc3=Image('雅典衛城.jpg')
pc4=Image('北村韓屋村.jpg')
pc5=Image('黃石國家公園.jpg')
pc6=Image('大堡礁.jpg')
pc7=Image('大笨鐘.jpg')
pc8=Image('巴黎聖母院.jpg')
pc9=Image('新天鵝堡.jpg')
pc10=Image('巴特略之家.jpg')
pc11=Image('聖瓦里西主教座堂.jpg')

# %%
msg="country"
print("想去哪玩?")
while(msg!="不想動"):
    msg=input(">> ")
    if ("日本"in msg):
        print("大阪城!!")
        display(pc1)
    elif ("義大利"in msg):
        print("羅馬競技場!!")
        display(pc2)
    elif ("希臘"in msg):
        print("雅典衛城!!")
        display(pc3)
    elif ("韓國"in msg):
        print("北村韓屋村!!")
        display(pc4)
    elif ("美國"in msg):
        print("黃石國家公園!!")
        display(pc5)
    elif ("澳洲"in msg):
        print("大堡礁!!")
        display(pc6)
    elif ("英國"in msg):
        print("大笨鐘!!")
        display(pc7)
    elif ("法國"in msg):
        print("巴黎聖母院!!")
        display(pc8)
    elif ("德國"in msg):
        print("新天鵝堡!!")
        display(pc9)
    elif ("西班牙"in msg):
        print("巴特略之家!!")
        display(pc10)
    elif ("俄羅斯"in msg):
        print("聖瓦里西主教座堂!!")
        display(pc11)
    else:
        print("在家睡覺吧!")
# Out:
# 想去哪玩?
# >> 義大利
# 羅馬競技場!!
# >> 澳洲
# 大堡礁!!
# >> 日本
# 大阪城!!
# >> 西班牙
# 巴特略之家!!
# >> 法國
# 巴黎聖母院!!
# >> 德國
# 新天鵝堡!!
