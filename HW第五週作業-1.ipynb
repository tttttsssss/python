# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display,HTML,Markdown,Image,YouTubeVideo

# %% [markdown]
# # 作業一：心情點播機(改良版)

# %%
def f(Mood):
    print(Mood)

song1=YouTubeVideo('HK7SPnGSxLM')
song2=YouTubeVideo('VyJS1qdNAmQ')
song3=YouTubeVideo('hr8jWDyb1jg')
song4=YouTubeVideo('NbNPJr_0tqA')
song5=YouTubeVideo('Mqr-kjvXsk8')
song6=YouTubeVideo('xWTiOqJqkk0')

# %%
msg="mood"
print("心情如何?來首歌吧!")
while(msg!="不想聽歌"):
    msg=input(">> ")
    if("想哭"in msg):
        display(song1)
    elif("餓"in msg):
        display(song2)
    elif("開心"in msg):
        display(song3)
    elif("累"in msg):
        display(song4)
    elif("暈"in msg):
        display(song5)
    elif("難過"in msg):
        display(song6)
    else:
        print("OK fine ~")
# Out:
# 心情如何?來首歌吧!
# >> 想哭
# >> 難過
# >> 不想聽歌
# OK fine ~
